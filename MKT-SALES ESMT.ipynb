# %% [markdown]
# ## Dataframe - Column Descriptions
#
# 1. **Age**:
#    - 1: 16 to 25 years
#    - 2: 26 to 35 years
#    - 3: 36 to 45 years
#    - 4: 45 to 55 years
#    - 5: 56 years to 65 years
#    - 6: More than 66 years old
#
# 2. **Gender**:
#    - 1: Male
#    - 2: Female
#    - 3: Other
#
# 3. **Residence Area**:
#    - 1: Africa
#    - 2: Antarctica
#    - 3: Asia
#    - 4: Europe
#    - 5: North America
#    - 6: Oceania
#    - 7: South America
#
# 4. **Favorite Video Call Tool**:
#    - 1: Microsoft Teams
#    - 2: Zoom
#    - 3: FaceTime
#    - 4: Google Meet
#    - 5: Skype
#    - 6: Other
#    - 7: Don't use any
#
# 5. **For Business or Non-Business**:
#    - 1: For Business
#    - 2: Non-Business
#
# 6. **Favorite Business Communication Tool**:
#    - 1: Microsoft Teams
#    - 2: Slack
#    - 3: Zoom
#    - 4: Google Meet
#    - 5: Cisco
#    - 6: Other
#    - 7: Don't Use any
#
# 7. **Main purpose of Use**:
#    - 1: Video Call
#    - 2: Chat/Messaging
#    - 3: Sharing Files
#    - 4: Other
#
# 8-13. **Satisfactions Columns**:
#    - These columns contain ratings on a scale of 1 to 5, indicating satisfaction levels with various aspects of Microsoft Teams.
#    - Column 8: Overall satisfaction with Microsoft Teams in meeting your needs
#    - Column 9: Ease of navigating and using Microsoft Teams
#    - Column 10: Satisfaction with the range of features and capabilities offered by Microsoft Teams
#    - Column 11: Confidence in the security measures implemented in Microsoft Teams
#    - Column 12: Reliability of the performance of Microsoft Teams in terms of audio and video quality
#    - Column 13: Accessibility of Microsoft Teams across different devices and platforms
#
# 14-18. **Importance ratings for Microsoft Teams features**:
#    - These columns contain ratings on a scale of 1 to 5, indicating the importance of specific features in using Microsoft Teams.
#    - Column 14: Usability (simplicity to use)
#    - Column 15: Functionality
#    - Column 16: Security
#    - Column 17: Stability
#    - Column 18: Accessibility
#
# (18 columns, 111 rows)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import FactorAnalysis
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import FactorAnalysis
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import FactorAnalysis
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('rawdata(Numerical Data).xlsx')

# %%
df
# Out:
#      Age  Gender  Continent  Video Call Tool  Type Business  Tool  \
# 0    2.0     1.0          2                1            1.0     1
# 1    4.0     2.0          2                1            1.0     1
# 2    3.0     2.0          3                1            2.0     5
# 3    2.0     2.0          6                1            1.0     1
# 4    2.0     2.0          6                5            2.0     1
# ..   ...     ...        ...              ...            ...   ...
# 106  2.0     2.0          5                2            1.0     1
# 107  3.0     1.0          2                4            1.0     4
# 108  2.0     1.0          2                1            1.0     2
# 109  2.0     2.0          3                4            1.0     3
# 110  2.0     2.0          2                2            1.0     1
#
#      Main purpose of Use  Satisfaction  Navigating  Features  Security  \
# 0                      1             3           2         2       4.0
# ...

# %%
# Define the new column names
new_column_names = ['Age', 'Gender', 'Residence Area', 'Favorite Video Call Tool', 'For Business or Non-Business',
                    'Favorite Business Communication Tool', 'Main purpose of Use',
                    'How satisfied are you with Microsoft Teams in meeting your overall needs?',
                    'How would you rate the ease of navigating and using Microsoft Teams?',
                    'How satisfied are you with the range of features and capabilities offered by Microsoft Teams?',
                    'How confident do you feel about the security measures implemented in Microsoft Teams for protecting sensitive business/personal information?',
                    'How reliable is the performance of Microsoft Teams in terms of audio and video quality during meetings or calls?',
                    'How accessible is Microsoft Teams across different devices and platforms (e.g., desktop, mobile, web, tablet)?',
                    'How important do you feel about the Usability in using Microsoft Teams?',
                    'How important do you feel about the Functionality in using Microsoft Teams?',
                    'How important do you feel about the Security in using Microsoft Teams?',
                    'How important do you feel about the Stability in using Microsoft Teams?',
                    'How important do you feel about the Accessibility in using Microsoft Teams?']

# Rename the columns
df.rename(columns=dict(zip(df.columns, new_column_names)), inplace=True)

# %%
df
# Out:
#      Age  Gender  Residence Area  Favorite Video Call Tool  \
# 0    2.0     1.0               2                         1
# 1    4.0     2.0               2                         1
# 2    3.0     2.0               3                         1
# 3    2.0     2.0               6                         1
# 4    2.0     2.0               6                         5
# ..   ...     ...             ...                       ...
# 106  2.0     2.0               5                         2
# 107  3.0     1.0               2                         4
# 108  2.0     1.0               2                         1
# 109  2.0     2.0               3                         4
# 110  2.0     2.0               2                         2
#
#      For Business or Non-Business  Favorite Business Communication Tool  \
# 0                             1.0                                     1
# 1                             1.0                                     1
# ...

# %%
# Find NaN values and replace them with the mean
data = df.fillna(df.mean())

# %%
# Round the values in the DataFrame to the nearest integer
data = data.round().astype(int)

# %%
data
# Out:
#      Age  Gender  Residence Area  Favorite Video Call Tool  \
# 0      2       1               2                         1
# 1      4       2               2                         1
# 2      3       2               3                         1
# 3      2       2               6                         1
# 4      2       2               6                         5
# ..   ...     ...             ...                       ...
# 106    2       2               5                         2
# 107    3       1               2                         4
# 108    2       1               2                         1
# 109    2       2               3                         4
# 110    2       2               2                         2
#
#      For Business or Non-Business  Favorite Business Communication Tool  \
# 0                               1                                     1
# 1                               1                                     1
# ...

# %%
# Assuming your DataFrame is named 'df'
column_names = data.columns

# Print the column names
for column in column_names:
    print(column)
# Out:
# Age
# Gender
# Residence Area
# Favorite Video Call Tool
# For Business or Non-Business
# Favorite Business Communication Tool
# Main purpose of Use
# How satisfied are you with Microsoft Teams in meeting your overall needs?
# How would you rate the ease of navigating and using Microsoft Teams?
# How satisfied are you with the range of features and capabilities offered by Microsoft Teams?
# How confident do you feel about the security measures implemented in Microsoft Teams for protecting sensitive business/personal information?
# How reliable is the performance of Microsoft Teams in terms of audio and video quality during meetings or calls?
# How accessible is Microsoft Teams across different devices and platforms (e.g., desktop, mobile, web, tablet)?
# How important do you feel about the Usability in using Microsoft Teams?
# How important do you feel about the Functionality in using Microsoft Teams?
# How important do you feel about the Security in using Microsoft Teams?
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_matrix = data.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# Identify variables with high correlation coefficients
threshold = 0.7  # Define the threshold for high correlation
highly_correlated = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) >= threshold:
            variable_i = correlation_matrix.columns[i]
            variable_j = correlation_matrix.columns[j]
            highly_correlated.append((variable_i, variable_j, correlation_matrix.iloc[i, j]))

# Print highly correlated variables
if len(highly_correlated) > 0:
    print("Highly correlated variables:")
    for variables in highly_correlated:
        print(f"{variables[0]} and {variables[1]} (correlation coefficient: {variables[2]:.2f})")
else:
    print("No highly correlated variables found.")
# Out:
# No highly correlated variables found.

# %%
# Scale the data for factor analysis
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data)

# %%
# Perform factor analysis
factor_analysis = FactorAnalysis(n_components=df_scaled.shape[1], random_state=42)
factor_scores = factor_analysis.fit_transform(df_scaled)

# Calculate eigenvalues
cov_matrix = factor_analysis.get_covariance()
eigenvalues, _ = np.linalg.eig(cov_matrix)
eigenvalues = np.real(eigenvalues)

# Sort eigenvalues in descending order
eigenvalues_sorted = np.sort(eigenvalues)[::-1]

# Calculate explained variance ratio
explained_variance_ratio = eigenvalues_sorted / eigenvalues_sorted.sum()
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plot scree plot
plt.plot(range(1, df_scaled.shape[1] + 1), cumulative_variance, marker='o', linestyle='-')
plt.axvline(x=5, color='r', linestyle='--')  # Add a vertical line at 5 factors
plt.xlabel('Number of Factors')
plt.ylabel('Cumulative Variance Explained')
plt.title('Scree Plot')
plt.xticks(range(1, df_scaled.shape[1] + 1))
plt.show()

# %%
# Calculate eigenvalues
cov_matrix = factor_analysis.get_covariance()
eigenvalues, _ = np.linalg.eig(cov_matrix)
eigenvalues = np.real(eigenvalues)

# Sort eigenvalues in descending order
eigenvalues_sorted = np.sort(eigenvalues)[::-1]

# Plot scree plot
plt.plot(range(1, df_scaled.shape[1] + 1), eigenvalues_sorted, marker='o', linestyle='-')
plt.axhline(y=1, color='r', linestyle='--')  # Threshold line (adjust the threshold value as needed)
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalues')
plt.title('Scree Plot')
plt.xticks(range(1, df_scaled.shape[1] + 1))
plt.show()

#Eigenvalues above the threshold line may be considered significant, while those below the line may be considered less significant.

# %% [markdown]
# **Principle Components Analysis / Identifying underlying factors or dimensions:**

# %%
import numpy as np
import pandas as pd
from factor_analyzer import FactorAnalyzer

# Convert df_scaled to DataFrame
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# Calculate eigenvalues of the correlation matrix
correlation_matrix = np.corrcoef(df_scaled.T)
eigenvalues, _ = np.linalg.eig(correlation_matrix)

# Sort eigenvalues in descending order
sorted_eigenvalues = np.sort(eigenvalues)[::-1]

# Calculate cumulative variance explained
cumulative_variance = np.cumsum(sorted_eigenvalues) / np.sum(sorted_eigenvalues)

# Print the cumulative variance explained by each factor
print("Cumulative Variance Explained:")
for i, variance in enumerate(cumulative_variance[:5]):
    factor_name = f"Factor {i+1}"
    print(f"{factor_name}: {variance:.2%}")

# Perform factor analysis
n_factors = 5
factor_analyzer = FactorAnalyzer(n_factors=n_factors, rotation=None)
factor_analyzer.fit(df_scaled)

# Get the factor loadings from the factor analyzer object
factor_loadings = factor_analyzer.loadings_

# Number of top loading variables to consider
top_loading_vars = 3

# Get the indices of variables with highest loadings for each factor
top_loading_indices = np.argsort(np.abs(factor_loadings), axis=0)[::-1][:top_loading_vars]

# Get the names of the variables from your original data
variable_names = list(df_scaled.columns)

# Print the variables with highest loadings for each factor
print("\nFactor Loadings:")
for i, factor_index in enumerate(top_loading_indices.T):
    factor_name = f"Factor {i+1}"
    variable_names_selected = [variable_names[j] for j in factor_index]
    print(f"{factor_name}: {variable_names_selected}")
# Out:
# Cumulative Variance Explained:
# Factor 1: 26.05%
# Factor 2: 38.60%
# Factor 3: 48.54%
# Factor 4: 55.63%
# Factor 5: 61.53%
#
# Factor Loadings:
# Factor 1: ['How satisfied are you with Microsoft Teams in meeting your overall needs?', 'How important do you feel about the Functionality in using Microsoft Teams?', 'How important do you feel about the Accessibility in using Microsoft Teams?']
# Factor 2: ['How important do you feel about the Stability in using Microsoft Teams?', 'How satisfied are you with Microsoft Teams in meeting your overall needs?', 'How important do you feel about the Usability in using Microsoft Teams?']
# Factor 3: ['Gender', 'Favorite Business Communication Tool', 'Favorite Video Call Tool']
# Factor 4: ['Gender', 'Favorite Video Call Tool', 'Favorite Business Communication Tool']
# Factor 5: ['How important do you feel about the Security in using Microsoft Teams?', 'Main purpose of Use', 'Favorite Video Call Tool']

# %%
# Define the item names corresponding to the columns of your dataset
item_names = df_scaled.columns

# Sort the component loadings by size
sorted_loadings = np.sort(np.abs(factor_analyzer.loadings_), axis=0)[::-1]

# Display component loadings greater than 0.35
selected_loadings = sorted_loadings[sorted_loadings > 0.35]

# Print the loadings matrix
print("Loadings Matrix:")
for i, factor_loading in enumerate(factor_analyzer.loadings_.T):
    factor_name = f"Factor {i+1}"
    loading_values = [(item_name, loading) for item_name, loading in zip(item_names, factor_loading)]
    loading_str = "\n".join([f"{item}: {loading:.3f}" for item, loading in loading_values])
    print(f"{factor_name}:\n{loading_str}\n")

# Print communalities
print("Communalities:")
for i, comm in enumerate(factor_analyzer.get_communalities()):
    item_name = item_names[i]
    print(f"{item_name}: {comm:.3f}")
print()

# Print specificities
print("Specificities:")
for i, spec in enumerate(factor_analyzer.get_uniquenesses()):
    item_name = item_names[i]
    print(f"{item_name}: {spec:.3f}")
print()

# Calculate factor scores
factor_scores = factor_analyzer.transform(df_scaled)
print("Factor Scores:")
print(factor_scores)
# Out:
# Loadings Matrix:
# Factor 1:
# Age: -0.089
# Gender: -0.009
# Residence Area: 0.266
# Favorite Video Call Tool: -0.183
# For Business or Non-Business: 0.052
# Favorite Business Communication Tool: 0.009
# Main purpose of Use: -0.059
# How satisfied are you with Microsoft Teams in meeting your overall needs?: 0.733
# How would you rate the ease of navigating and using Microsoft Teams?: 0.687
# How satisfied are you with the range of features and capabilities offered by Microsoft Teams?: 0.655
# How confident do you feel about the security measures implemented in Microsoft Teams for protecting sensitive business/personal information?: 0.284
# How reliable is the performance of Microsoft Teams in terms of audio and video quality during meetings or calls?: 0.519
# How accessible is Microsoft Teams across different devices and platforms (e.g., desktop, mobile, web, tablet)?: 0.531
# How important do you feel about the Usability in using Microsoft Teams?: 0.649
# ...

# %% [markdown]
# **Factor 1: Overall Satisfaction and Functionality**
# This factor is characterized by high loadings on variables related to overall satisfaction with Microsoft Teams and the importance of functionality in using the platform. Users who score high on this factor are likely to be satisfied with Microsoft Teams and consider functionality as an essential aspect of their experience. Variables such as satisfaction with meeting overall needs, ease of navigating the platform, and satisfaction with the range of features contribute significantly to this factor.
#
# **Factor 2: Stability and Usability**
# Factor 2 represents the importance of stability and usability in using Microsoft Teams. Users who score high on this factor value the stability of the platform and its ease of use. They prioritize factors such as reliability in terms of audio and video quality during meetings or calls, as well as the stability and accessibility of the platform.
#
# **Factor 3: Communication Preferences and Tool Usage**
# This factor focuses on the preferred communication tools and methods used for business communication. It includes variables such as the preferred business communication tool and the preferred video call tool. Users who score high on this factor may have specific preferences when it comes to the tools they use for business communication, regardless of their gender.
#
# **Factor 4: Gender and Communication Tool Preferences**
# Factor 4 explores people's choices when it comes to communication tools, particularly video call and business communication tools. It reveals the connection between gender and preferred tools for these purposes.
#
# **Factor 5: Security and Usage Purpose**
# This factor encompasses users' perception of the security measures implemented in Microsoft Teams and the main purpose of usage, such as video calls, messaging, or file sharing. It captures the importance users place on security and the specific purposes for which they use the platform.

# %%
import numpy as np

# Get the factor loadings from the factor analyzer object
factor_loadings = factor_analyzer.loadings_

# Calculate the SS loadings for each component
ss_loadings = np.sum(factor_loadings ** 2, axis=0)

# Print the SS loadings for each component
print("SS Loadings:")
for i, ss_loading in enumerate(ss_loadings):
    component_name = f"PC{i+1}"
    print(f"{component_name}: {ss_loading:.3f}")
# Out:
# SS Loadings:
# PC1: 4.305
# PC2: 1.831
# PC3: 1.261
# PC4: 0.975
# PC5: 0.507

# %% [markdown]
# The SS Loadings for these components provide information about how much of the total variance in the original variables is accounted for by each component.
#
# For example, PC1 has an SS Loading of 4.305. This means that PC1 explains a significant amount of the variance in the data, indicating that it captures an important underlying pattern. Similarly, PC2 explains 1.831 units of variance, PC3 explains 1.261 units, PC4 explains 0.975 units, and PC5 explains 0.507 units.

# %% [markdown]
# **Regression for all the variables**

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Set the dependent variable
y = df_scaled['How satisfied are you with Microsoft Teams in meeting your overall needs?']

# Set the independent variables
X = df_scaled.drop('How satisfied are you with Microsoft Teams in meeting your overall needs?', axis=1)

# Add a constant column to the independent variables
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                                                         OLS Regression Results
# ...
# Dep. Variable:     How satisfied are you with Microsoft Teams in meeting your overall needs?   R-squared:                       0.721
# Model:                                                                                   OLS   Adj. R-squared:                  0.670
# Method:                                                                        Least Squares   F-statistic:                     14.14
# Date:                                                                       Wed, 05 Jul 2023   Prob (F-statistic):           6.65e-19
# Time:                                                                               18:02:53   Log-Likelihood:                -86.655
# No. Observations:                                                                        111   AIC:                             209.3
# ...

# %%
# Sort the absolute coefficients in descending order
abs_coefs = abs(results.params.drop('const')).sort_values(ascending=False)

# Plot the coefficients
plt.figure(figsize=(10, 6))
abs_coefs.plot(kind='bar')
plt.xlabel('Variables')
plt.ylabel('Absolute Coefficients')
plt.title('Variables Most Linked to How satisfied are you with Microsoft Teams in meeting your overall needs?')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Regression using our 5 dimensions/factors**

# %%
import statsmodels.api as sm

# Set the independent variables
X = factor_scores[:, [0, 1, 2, 3, 4]]  # Assuming Factor1 to Factor5 are the first 5 columns

# Add a constant column to the independent variables
X = sm.add_constant(X)

# Set the dependent variable
y = df_scaled['How satisfied are you with Microsoft Teams in meeting your overall needs?']

# Fit the regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                                                         OLS Regression Results
# ...
# Dep. Variable:     How satisfied are you with Microsoft Teams in meeting your overall needs?   R-squared:                       0.875
# Model:                                                                                   OLS   Adj. R-squared:                  0.869
# Method:                                                                        Least Squares   F-statistic:                     146.8
# Date:                                                                       Wed, 05 Jul 2023   Prob (F-statistic):           1.01e-45
# Time:                                                                               18:02:54   Log-Likelihood:                -42.166
# No. Observations:                                                                        111   AIC:                             96.33
# ...

# %% [markdown]
# The regression analysis provides important insights into the relationship between the factors and the satisfaction level with Microsoft Teams. Here are some key points to consider from the regression results:
#
# 1. R-squared and Adj. R-squared: The R-squared value of 0.843 indicates that approximately 84.3% of the variation in the satisfaction level can be explained by the selected factors. The Adjusted R-squared of 0.835 suggests that the model's goodness of fit remains high even after considering the number of predictors.
#
# 2. Coefficients: The coefficients represent the estimated effect of each factor on the satisfaction level. The constant term is -2.368e-16, which is close to zero. The coefficients for x1, x2, x4, and x5 are statistically significant as their p-values are less than 0.05. It suggests that these factors have a significant impact on the satisfaction level.
#
# 3. Interpretation of Coefficients: The coefficient for x1 (-0.7720) indicates that a one-unit decrease in Factor 1 is associated with a decrease in the satisfaction level by 0.7720 units. Similarly, a one-unit increase in x2, x4, and x5 is associated with an increase in the satisfaction level by 0.5823, 0.3266, and -0.2386 units, respectively.
#
# 4. Significance of Factors: Factors x1, x2, x4, and x5 are significant predictors of the satisfaction level, as their coefficients have a statistically significant impact on the dependent variable.
#
# 5. Factors x3: The coefficient for x3 is not statistically significant (p-value > 0.05), suggesting that it does not have a significant impact on the satisfaction level.
#
# 6. Interpretation of R-squared: The high R-squared value indicates that the selected factors explain a large proportion of the variation in the satisfaction level. However, there may be other factors or variables not included in the analysis that could also contribute to the satisfaction level.
#
# 7. Assumptions: The regression analysis assumes no multicollinearity, homoscedasticity, and normality of residuals. It is important to check these assumptions and consider potential violations to ensure the validity of the results.
#
# **Based on the coefficients and their significance levels:
#
# **Factor 1 has a negative impact on the satisfaction level with Microsoft Teams. An increase in x1 is associated with a decrease in satisfaction.**
#
# **Factor 2 has a positive impact on the satisfaction level with Microsoft Teams. An increase in x2 is associated with an increase in satisfaction.**
#
# **Factor 3 does not have a statistically significant impact on the satisfaction level. Its coefficient is not significantly different from zero.**
#
# **Factor 4 has a positive impact on the satisfaction level with Microsoft Teams. An increase in x4 is associated with an increase in satisfaction.**
#
# **Factor 5 has a negative impact on the satisfaction level with Microsoft Teams. An increase in x5 is associated with a decrease in satisfaction.**
#
# It's important to note that the p-value for Factor x3 is relatively high (0.199), suggesting that its relationship with satisfaction may not be statistically significant at conventional significance levels (e.g., 0.05). However, it is described as marginally significant, indicating the possibility of a weaker impact.
#
# The overall model provides valuable insights into the factors influencing satisfaction with Microsoft Teams, with an R-squared value of 0.843.

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Initialize lists to store WCSS values
wcss = []

# Set the range of clusters to test
num_clusters = range(1, 11)

# Calculate WCSS for each number of clusters
for k in num_clusters:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)

# Plot the WCSS values
plt.plot(num_clusters, wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')

# Add a vertical line for the chosen number of clusters
chosen_clusters = 3
plt.axvline(x=chosen_clusters, color='r', linestyle='--', label=f'{chosen_clusters} Clusters')
plt.legend()

plt.show()
# Out:
# /Users/matiasgroblunecke/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/matiasgroblunecke/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/matiasgroblunecke/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# **Performing Cluster Analysis (3 Clusters) using Factor Scores:**

# %%
from sklearn.cluster import KMeans

# Perform K-means clustering on factor scores
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(factor_scores)

# Assign cluster labels to the original dataframe
df_scaled['Cluster'] = clusters

# Explore the clusters and their characteristics
cluster_counts = df_scaled['Cluster'].value_counts()
cluster_means = df_scaled.groupby('Cluster').mean()

# Print the number of respondents in each cluster
print("Cluster Counts:")
print(cluster_counts)

# Print the mean values of each column for each cluster
print("\nCluster Means:")
print(cluster_means)
# Out:
# Cluster Counts:
# 0    57
# 2    32
# 1    22
# Name: Cluster, dtype: int64
#
# Cluster Means:
#               Age    Gender  Residence Area  Favorite Video Call Tool  \
# Cluster
# 0        0.169791  0.692820        0.120572                 -0.237320
# 1       -0.117235  0.304421       -0.068223                  0.683747
# 2       -0.221841 -1.443376       -0.167865                 -0.047350
#
#          For Business or Non-Business  Favorite Business Communication Tool  \
# Cluster
# 0                           -0.075174                             -0.137015
# 1                            0.248607                              0.251252
# 2                           -0.037014                              0.071323
#
#          Main purpose of Use  \
# Cluster
# 0                  -0.058670
# 1                   0.409108
# 2                  -0.176756
#
#          How satisfied are you with Microsoft Teams in meeting your overall needs?  \
# Cluster
# ...

# %% [markdown]
# **Performing Cluster Analysis (3 Clusters) using our 5 Factor Scores:**

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Perform cluster analysis on factor scores
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(factor_scores[:, :5])  # Assuming the first 5 columns represent your 5 factors

# Create a DataFrame with the factor scores and cluster labels
factor_data = pd.DataFrame(factor_scores[:, :5], columns=['Factor1', 'Factor2', 'Factor3', 'Factor4', 'Factor5'])
factor_data['Cluster'] = clusters

# Demographic profiling by cluster
demographic_profile = factor_data.groupby('Cluster').mean()

# Display the demographic profile
print(demographic_profile)
# Out:
# /Users/matiasgroblunecke/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           Factor1   Factor2   Factor3   Factor4   Factor5
# Cluster
# 0        0.402606  0.051171 -0.534941  0.466792 -0.030193
# 1       -1.356309  0.598503  0.133790  0.342375 -0.002847
# 2        0.215319 -0.502619  0.860883 -1.066856  0.055739

# %% [markdown]
# **Adding demographic:**

# %%
import pandas as pd
from sklearn.cluster import KMeans

# Combine factor scores, age, gender, and residence area into a single DataFrame
data = pd.DataFrame({
    'Factor1': factor_scores[:, 0],
    'Factor2': factor_scores[:, 1],
    'Factor3': factor_scores[:, 2],
    'Factor4': factor_scores[:, 3],
    'Factor5': factor_scores[:, 4],
    'Age': df['Age'],  # Replace 'Age' with the correct column name from your dataframe
    'Gender': df['Gender'],  # Replace 'Gender' with the correct column name from your dataframe
    'Residence Area': df['Residence Area']  # Replace 'Residence Area' with the correct column name from your dataframe
})

# Perform cluster analysis on the combined data
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(data[['Factor1', 'Factor2', 'Factor3', 'Factor4', 'Factor5']])

# Create a DataFrame with the factor scores, demographic information, and cluster labels
cluster_data = data.copy()
cluster_data['Cluster'] = clusters

# Demographic profiling by cluster
demographic_profile = cluster_data.groupby('Cluster').mean()

# Display the demographic profile
print(demographic_profile)
# Out:
# /Users/matiasgroblunecke/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           Factor1   Factor2   Factor3   Factor4   Factor5       Age    Gender  \
# Cluster
# 0        0.402606  0.051171 -0.534941  0.466792 -0.030193  3.178571  2.000000
# 1       -1.356309  0.598503  0.133790  0.342375 -0.002847  2.863636  1.818182
# 2        0.215319 -0.502619  0.860883 -1.066856  0.055739  2.750000  1.000000
#
#          Residence Area
# Cluster
# 0              3.263158
# 1              3.090909
# 2              3.000000

# %% [markdown]
# **Cluster 0:Cluster 0: Moderate Satisfaction, System Limitations**
# Users in this cluster have relatively low scores in Factor 1, Factor 2, and Factor 4, suggesting that they may have lower satisfaction with Microsoft Teams regarding user satisfaction, accessibility, system stability, and usability. However, they have average scores in Factor 3 and Factor 5, indicating that video call tool preferences and security measures may not be significant factors for their satisfaction. In terms of demographic variables, users in this cluster have an average age of 2.82 (between 36 to 45 years), predominantly identify as male (gender score of 1.68), and reside primarily in Asia (residence area score of 3.28).
#
# **Cluster 1:Cluster 1: High Satisfaction, System Improvement Needed**
# This cluster represents users who have high scores in Factor 1 and Factor 3, indicating that they are more satisfied with Microsoft Teams in terms of user satisfaction, accessibility, and video call tool preferences. However, they have relatively low scores in Factor 2, Factor 4, and Factor 5, suggesting that system stability, usability, and security measures may be areas where improvement is needed for this group. Demographically, users in this cluster have an average age of 3.26 (between 45 to 55 years), predominantly identify as male (gender score of 1.53), and reside primarily in Europe (residence area score of 2.68).
#
# **Cluster 2:High Satisfaction, System Excellence**
# Users in this cluster exhibit high scores in Factor 1, Factor 2, and Factor 5, indicating that they have higher satisfaction levels with Microsoft Teams regarding user satisfaction, accessibility, system stability, usability, and security measures. They also have average scores in Factor 3, suggesting that video call tool preferences may not be as significant for their satisfaction. In terms of demographic variables, users in this cluster have an average age of 3.16 (between 36 to 45 years), predominantly identify as male (gender score of 1.74), and reside primarily in Asia (residence area score of 3.19).

# %% [markdown]
# **Cluster Distribution (Bar Chart):**

# %%
# Plot bar chart for cluster distribution
plt.figure(figsize=(8, 6))
cluster_counts.plot(kind='bar')
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.title('Cluster Distribution')
plt.show()

# %% [markdown]
# **Cluster Profiles (Grouped Bar Chart):**

# %%
# Define the column names
column_names = ['Age', 'Gender', 'Residence Area', 'Favorite Video Call Tool', 'For Business or Non-Business',
                'Favorite Business Communication Tool', 'Main purpose of Use',
                'How satisfied are you with Microsoft Teams in meeting your overall needs?',
                'How would you rate the ease of navigating and using Microsoft Teams?',
                'How satisfied are you with the range of features and capabilities offered by Microsoft Teams?',
                'How confident do you feel about the security measures implemented in Microsoft Teams for protecting sensitive business/personal information?',
                'How reliable is the performance of Microsoft Teams in terms of audio and video quality during meetings or calls?',
                'How accessible is Microsoft Teams across different devices and platforms (e.g., desktop, mobile, web, tablet)?',
                'How important do you feel about the Usability in using Microsoft Teams?',
                'How important do you feel about the Functionality in using Microsoft Teams?',
                'How important do you feel about the Security in using Microsoft Teams?',
                'How important do you feel about the Stability in using Microsoft Teams?',
                'How important do you feel about the Accessibility in using Microsoft Teams?']

# Get the cluster means
cluster_means_transposed = cluster_means.T.abs()

# Plot grouped bar chart for cluster profiles
x = np.arange(len(column_names))
width = 0.2

plt.figure(figsize=(12, 6))
for i, cluster in enumerate(cluster_means_transposed.columns):
    plt.bar(x + (i * width), cluster_means_transposed[cluster], width, label=f'Cluster {cluster}')

plt.xlabel('Variables')
plt.ylabel('Mean Values (Absolute)')
plt.title('Cluster Profiles')
plt.xticks(x, column_names, rotation=90)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/y5/7v3j89sd4ps24p3x50lkvwf80000gn/T/ipykernel_8255/3489390858.py:32: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# **Scatter Plot:**

# %%
# Plot scatter plot for 2D visualization of clusters
plt.figure(figsize=(8, 6))
plt.scatter(factor_scores[:, 0], factor_scores[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Factor 1')
plt.ylabel('Factor 2')
plt.title('Cluster Visualization')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# **Box Plots:**

# %%
import seaborn as sns

# Plot box plots for each variable
plt.figure(figsize=(12, 10))

# Create subplots
for i, col in enumerate(df.columns[:-1]):
    ax = plt.subplot(3, 6, i+1)

    # Plot box plot
    sns.boxplot(y=col, data=df, ax=ax)

    # Set the variable label
    variable_label = f'Variable {i+1}'

    # Set title and labels with variable label
    plt.title(variable_label)
    plt.xlabel('Variable')
    plt.ylabel(variable_label)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
